# %%
age = int(input("請輸入年齡")) 
if age >= 18:
    print("成年")
else:
    print("未成年")
# Out:
# 請輸入年齡25
# 成年

# %% [markdown]
# ## 邏輯運算
#
# 且 and  學測分數4級分且需要Python認證 才可面試
#
# 或 or   5歲以下或65歲以上 半價
#
# 反向 not 不要真就是假 不要假就是真

# %%
b1 = True  #對 真 開 亮 有
b2 = False #錯 假 關 暗 無
print(b1 and b2)
print(b1 or b2)
print(not b1)
# Out:
# False
# True
# False

# %%
a = 4
c = True
if a >= 4 and c :
    print("可參加口試")
else:
    print("不可參加口試")
# Out:
# 可參加口試

# %%
age = 12
if age <= 5 or age >= 65:
    print("半價")
else:
    print("原價")
# Out:
# 原價

# %%
a = 15
if a >= 12 and a < 18:
    print("ok-1")
else:
    print("cancel-1")
# Out:
# ok-1

# %%
a = 15
if  12 <= a < 18:
    print("ok-2")
else:
    print("cancel-2")
# Out:
# ok-2

# %%
a = 18

if not a > 18:
    print("ok-3")
else:
    print("cancel-3")
# Out:
# ok-3

# %%
a = 9
if a > 18:
    print("大於18")
elif a > 12:
    print("大於12")
elif a > 6:
    print("大於6")
else:
    print("小於6")
# Out:
# 大於6

# %% [markdown]
# ## 作業
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
# 體重/身高(公尺)^2
h = input("身高多少公分")
w = input("體重多少公斤")
h = int(h)
w = int(w)
bmi = w / (h/100)**2
print(bmi)
print(round(bmi,2) )
# Out:
# 身高多少公分156
# 體重多少公斤77
# 31.640368178829714
# 31.64

# %% [markdown]
# ## 迴圈

# %%
for i in range(4):
    print(i)
# Out:
# 0
# 1
# 2
# 3

# %%
for x in range(6,10):
    print(x)
# Out:
# 6
# 7
# 8
# 9

# %%
for y in range(3,20,2):#開始 結束 累加數
    print(y)
# Out:
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19

# %%
for a in range(4,0,-1):
    print(a)
# Out:
# 4
# 3
# 2
# 1

# %%
a = 6
while a > 0:
    print(a)
    a-=1
print("end:",a)
# Out:
# 6
# 5
# 4
# 3
# 2
# 1
# end: 0

# %%
a = 3
while a < 20:
    print(a)
    a += 2
# Out:
# 3
# 5
# 7
# 9
# 11
# 13
# 15
# 17
# 19

# %% [markdown]
# ## 中斷迴圈

# %%
for v in range(1,6):
    if v == 4:
        break
    print(v)
# Out:
# 1
# 2
# 3

# %%
s = "大明"
name = ['曉華',"小民","大明","曉風"]
for n in name:
    if n == s:
        break
    print(n)
# Out:
# 曉華
# 小民

# %%
for i in range(1,5):
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
e = [False,True,False,True,True,False,False]
for v in e:
    if v:
        continue
    print("放入籃子")
# Out:
# 放入籃子
# 放入籃子
# 放入籃子
# 放入籃子

# %% [markdown]
# ## 字串

# %%
str1 = "你好Ken"
str2 = '午安Vivin'
print(str1,str2)
# Out:
# 你好Ken 午安Vivin

# %%
str3 = "你好'Ken'" #字串內使用到單引號 字串外使用雙引號
print(str3)
str4 = '午安"Vivin"'
print(str4)
# Out:
# 你好'Ken'
# 午安"Vivin"

# %%
str5 = """Google 今天宣布，很快就會在 Mac 版和 Windows 版 Chrome 中增加 3 項新的 AI 功能，
包括智慧分頁群組、自訂生成式 AI 主題，以及可以幫助使用者在網路上撰寫內容的寫作助理。
Google 終於在自家瀏覽器加入了生成式 AI 功能！Google 今天宣布，
很快就會在 Mac 版和 Windows 版 Chrome 中增加 3 項新的 AI 功能，
包括智慧分頁群組、自訂生成式 AI 主題，以及可以幫助使用者在網路上撰寫內容的寫作助理。"""
print(str5)
# Out:
# Google 今天宣布，很快就會在 Mac 版和 Windows 版 Chrome 中增加 3 項新的 AI 功能，
# 包括智慧分頁群組、自訂生成式 AI 主題，以及可以幫助使用者在網路上撰寫內容的寫作助理。
# Google 終於在自家瀏覽器加入了生成式 AI 功能！Google 今天宣布，
# 很快就會在 Mac 版和 Windows 版 Chrome 中增加 3 項新的 AI 功能，
# 包括智慧分頁群組、自訂生成式 AI 主題，以及可以幫助使用者在網路上撰寫內容的寫作助理。

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mystring2 = "ABCDEFGH"
print(mystring2[0])
print(mystring2[5])
print(mystring2[7])
print(mystring2[-1])
print(mystring2[-4])
print(mystring2[2:])
print(mystring2[2:5])#包含2不包含5
print(mystring2[4:7])#EFG
print(mystring2[-4:-1])#EFG
# Out:
# A
# F
# H
# H
# E
# CDEFGH
# CDE
# EFG
# EFG

# %%
str3 = "Java Python Golan C#"
str4 = str3.replace("P","p")#P變小寫p
print(str4)
print(str3)
# Out:
# Java python Golan C#
# Java Python Golan C#

# %%
str3 = "Java Python Golan C#"
print(str3.find("Python"))#找不到-1
print(str3.find("H"))
# Out:
# 5
# -1

# %%
names = ["Ken","Vivin","Joy"]
c = ","
joinStr =  c.join(names)
print(joinStr)
# Out:
# Ken,Vivin,Joy

# %%
str3 = "Java,Python,Golan,C#"
str5 = str3.split(",")
print(type(str5))
print(str5[0])

for name in str5:
    print(name)
# Out:
# <class 'list'>
# Java
# Java
# Python
# Golan
# C#

# %%
str3 = "A,B,A,C,B,A,C,B,A,A,B,G,B,A"
#幫我輸出A,B,C的筆數
strList = str3.split(",")
a=b=c=0
for v in strList:
    if v == "A":
        a+=1
    elif v == "B":
        b+=1
    elif v == "C":
        c+=1
print(f"A:{a}")        
print(f"B:{b}")
print(f"C:{c}")
# Out:
# A:6
# B:5
# C:2

# %% [markdown]
# ## List

# %%
myList = ["Ken","Vivin","Lucy"]
print(myList[1])
print(len(myList))
# Out:
# Vivin
# 3

# %% [markdown]
# ## Tuple 元組 不可變動 List可變動

# %%
myList2 = ["A","B","C"]
myList2[1] = "bb"
print(myList2)
myList2.append("E")
print(myList2)
# Out:
# ['A', 'bb', 'C']
# ['A', 'bb', 'C', 'E']

# %%
myTuple = ("A","B","C")
print(myTuple[1])
#myTuple.append("GGG")
#myTuple[1] = "bb"
# Out:
# B

# %%
myList3 = ["A","B","C","D","E","F"]
print(myList3[1:4])
print(myList3[-3:-1])
print(myList3[2:])
# Out:
# ['B', 'C', 'D']
# ['D', 'E']
# ['C', 'D', 'E', 'F']

# %%
myList4 = ["Ken","Vivin","Lucy"]
myList5 = []
for v in myList4:
    myList5.append(len(v))
print(myList5)
# Out:
# [3, 5, 4]
